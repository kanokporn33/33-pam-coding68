# %% [markdown]
# <a href="https://colab.research.google.com/github/kanokporn33/33-pam-coding68/blob/main/33_pam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pace = int(input("กรุณาใส่จำนวนก้าวที่คุณก้าวในวันนี้ลงไปค่ะ (ก้าว.)"))


if pace >= 10000 :
 print("ฟิตมาก")
else :
 print("เดินเพิ่ม")
# Out:
# กรุณาใส่จำนวนก้าวที่คุณก้าวในวันนี้ลงไปค่ะ (ก้าว.)50
# เดินเพิ่ม
